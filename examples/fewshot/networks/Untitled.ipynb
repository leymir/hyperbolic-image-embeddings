# %%
from convnet import ConvNet
import torch

# %%
from ResNet import resnet18

# %%
model1 = ConvNet(z_dim=512)

# %%
model2 = resnet18(remove_linear=True, zero_init_residual=False)

# %%
torch.norm(model1(torch.randn(1,3,84,84)))
# Out:
# tensor(56.5732, grad_fn=<NormBackward0>)

# %%
model2(torch.randn(1,3,84,84))
# Out:
# tensor([[4.7441, 3.6248, 4.1748, 4.0836, 6.0315, 4.2252, 4.8391, 4.0156, 4.9658,
#          4.3782, 3.1081, 6.0087, 6.7584, 3.5035, 4.7492, 4.4544, 3.8244, 4.5813,
#          4.7435, 5.7447, 5.0094, 3.7379, 3.5427, 6.3256, 6.2690, 5.6349, 5.0798,
#          4.7719, 3.6398, 4.0372, 4.5932, 5.4813, 4.8319, 3.9748, 4.4144, 4.6637,
#          3.7253, 4.6739, 4.3317, 4.2086, 4.9000, 5.5377, 3.9429, 5.7144, 3.2939,
#          5.4383, 5.1532, 5.2344, 5.5490, 6.0853, 5.7151, 3.9904, 4.7198, 4.4476,
#          4.5788, 4.0076, 6.0014, 4.7491, 4.9403, 5.0996, 4.7764, 3.6137, 4.0737,
#          5.6077, 4.3811, 3.3945, 3.4424, 4.2347, 4.6553, 5.0055, 4.4092, 3.6795,
#          3.1384, 4.0027, 4.1063, 3.6192, 5.3803, 4.4483, 6.4711, 4.7679, 3.9131,
#          5.4029, 4.1525, 4.0508, 4.8871, 5.1348, 4.0039, 3.7452, 3.8868, 4.3755,
#          4.6887, 3.6936, 4.3749, 5.5756, 5.1577, 4.0654, 4.5601, 5.1065, 2.9892,
#          4.5968, 5.3322, 4.3463, 5.5409, 5.3473, 3.4585, 4.0184, 5.3213, 3.5832,
# ...
